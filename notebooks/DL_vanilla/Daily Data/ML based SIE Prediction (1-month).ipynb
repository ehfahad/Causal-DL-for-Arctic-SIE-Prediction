# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

# %%
# global variables

look_back = 21
lead_time = 30
filename = '../../../data/Arctic_domain_mean_1979_2018 - Curated.csv'
pcmciplus_features = ['LW_down', 'snowfall', 'sst', 'sosaline', 'surface_pressure', 'sea_ice_extent']

# %%
# from google.colab import files
# import io

# uploaded = files.upload()
# df = pd.read_csv(io.BytesIO(uploaded[filename]))
# df = df[7305:]
# df

# Reading the dataset
df = pd.read_csv(filename)
df = df[7305:]
df.head()
# Out:
#            Day  wind_10m  specific_humidity     LW_down   SW_down  rainfall  \
# 7305  1/1/1999  4.987515           0.891843  183.786092  1.120906  0.700735
# 7306  1/2/1999  5.075952           0.905535  183.851814  1.193514  0.712730
# 7307  1/3/1999  4.931520           0.911672  184.426913  1.263909  0.677339
# 7308  1/4/1999  4.761644           0.911301  187.528326  1.269229  0.824016
# 7309  1/5/1999  4.739850           0.901353  187.326709  1.552208  0.926681
#
#       snowfall   sosaline         sst         t2m  surface_pressure  \
# 7305  0.501109  33.316996  273.467869  250.884060        985.112721
# 7306  0.482221  33.316996  273.453826  250.359328        984.092282
# 7307  0.480718  33.316996  273.454385  250.327500        982.300080
# 7308  0.697950  33.316996  273.459797  249.905730        983.250565
# 7309  0.835868  33.316996  273.463975  250.254873        984.247389
#
#       sea_ice_extent
# 7305        13823248
# 7306        13885522
# 7307        13884279
# 7308        13912624
# 7309        13890148

# %%
df['Day'] = pd.to_datetime(df['Day'], infer_datetime_format=True)
df.set_index('Day', inplace=True)
df = df.astype(float)                 # cast df to float
# df = df[pcmciplus_features]
# df.tail(len(df))
# Out:
# /tmp/ipykernel_3420/659794668.py:1: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df['Day'] = pd.to_datetime(df['Day'], infer_datetime_format=True)

# %%
def create_model_data (dataset, look_back, lead_time):
    dataX, dataY = [], []
    
    for i in range(len(dataset)-look_back-lead_time):
        a = dataset[i:(i+look_back)]
        dataX.append(a)
        dataY.append(dataset[i + look_back + lead_time])
    return np.array(dataX), np.array(dataY)

# %%
target_index = df.columns.tolist().index('sea_ice_extent')

dataset = df.values.astype('float32')               # DataFrame converted to Numpy Array

scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

X, y = create_model_data (dataset, look_back=look_back, lead_time=lead_time)
y = y[:,target_index]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# %%
plt.figure(figsize = (16,6))
ax = plt.axes()
# ax.set_facecolor('#dcdcdc')

plt.title('Arctic Sea Ice Extent Trend from 1979-2018', fontsize = 20,fontweight = "bold")
plt.xlabel('Time' , fontsize = 14,fontweight = "bold")
plt.ylabel('Sea Ice Extent (10\u2076 km\u00b2)', fontsize = 14,fontweight = "bold")
plt.plot(df['sea_ice_extent'][:len(df)-len(y_test)]/10**6, 'blue', label='Training Data')
plt.plot(df['sea_ice_extent'][len(df)-len(y_test):]/10**6, 'red', label='Testing Data')
plt.legend()
plt.grid()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Input, LSTM, GRU, Dense

input_shape=(X.shape[1], X.shape[2])

model = Sequential()
model.add(GRU(64, input_shape=(X.shape[1], X.shape[2]), return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(128))
model.add(Dropout(0.2))

model.add(Dense(64 ,  activation = 'relu'))
model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mae', 'mse'])
print(model.summary())
# Out:
# 2024-11-27 18:00:54.421233: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-27 18:00:54.521408: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-11-27 18:00:57.169692: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 21, 64)            14784
#
#  dropout (Dropout)           (None, 21, 64)            0
#
#  lstm (LSTM)                 (None, 128)               98816
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense (Dense)               (None, 64)                8256
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 121,921
# Trainable params: 121,921
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
from keras.callbacks import ModelCheckpoint
checkpoint = ModelCheckpoint("weights.best.hdf5", monitor='val_mean_squared_error', verbose=1, save_best_only=True, mode='min')

callbacks_list = [checkpoint]
history = model.fit(X_train, y_train, epochs=100, batch_size=64, verbose=1, callbacks=callbacks_list, validation_split=0.1)
# Out:
# Epoch 1/100
# 81/82 [============================>.] - ETA: 0s - loss: 0.0225 - mae: 0.0946 - mse: 0.0225WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 6s 41ms/step - loss: 0.0224 - mae: 0.0942 - mse: 0.0224 - val_loss: 0.0011 - val_mae: 0.0278 - val_mse: 0.0011
# Epoch 2/100
# 81/82 [============================>.] - ETA: 0s - loss: 0.0034 - mae: 0.0464 - mse: 0.0034WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 0.0034 - mae: 0.0463 - mse: 0.0034 - val_loss: 8.7558e-04 - val_mae: 0.0247 - val_mse: 8.7558e-04
# Epoch 3/100
# 81/82 [============================>.] - ETA: 0s - loss: 0.0028 - mae: 0.0420 - mse: 0.0028WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 0.0028 - mae: 0.0420 - mse: 0.0028 - val_loss: 0.0026 - val_mae: 0.0447 - val_mse: 0.0026
# Epoch 4/100
# 81/82 [============================>.] - ETA: 0s - loss: 0.0023 - mae: 0.0385 - mse: 0.0023WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 0.0023 - mae: 0.0385 - mse: 0.0023 - val_loss: 8.1865e-04 - val_mae: 0.0240 - val_mse: 8.1865e-04
# Epoch 5/100
# 81/82 [============================>.] - ETA: 0s - loss: 0.0021 - mae: 0.0367 - mse: 0.0021WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 0.0021 - mae: 0.0367 - mse: 0.0021 - val_loss: 0.0014 - val_mae: 0.0323 - val_mse: 0.0014
# Epoch 6/100
# 81/82 [============================>.] - ETA: 0s - loss: 0.0020 - mae: 0.0355 - mse: 0.0020WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 31ms/step - loss: 0.0020 - mae: 0.0355 - mse: 0.0020 - val_loss: 0.0010 - val_mae: 0.0275 - val_mse: 0.0010
# Epoch 7/100
# 81/82 [============================>.] - ETA: 0s - loss: 0.0017 - mae: 0.0332 - mse: 0.0017WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 0.0017 - mae: 0.0332 - mse: 0.0017 - val_loss: 8.2119e-04 - val_mae: 0.0246 - val_mse: 8.2119e-04
# Epoch 8/100
# 81/82 [============================>.] - ETA: 0s - loss: 0.0016 - mae: 0.0322 - mse: 0.0016WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 0.0016 - mae: 0.0322 - mse: 0.0016 - val_loss: 0.0010 - val_mae: 0.0278 - val_mse: 0.0010
# Epoch 9/100
# 81/82 [============================>.] - ETA: 0s - loss: 0.0015 - mae: 0.0313 - mse: 0.0015WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 0.0015 - mae: 0.0314 - mse: 0.0015 - val_loss: 7.0801e-04 - val_mae: 0.0225 - val_mse: 7.0801e-04
# Epoch 10/100
# 81/82 [============================>.] - ETA: 0s - loss: 0.0015 - mae: 0.0309 - mse: 0.0015WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 31ms/step - loss: 0.0015 - mae: 0.0308 - mse: 0.0015 - val_loss: 6.2241e-04 - val_mae: 0.0203 - val_mse: 6.2241e-04
# Epoch 11/100
# 81/82 [============================>.] - ETA: 0s - loss: 0.0015 - mae: 0.0307 - mse: 0.0015WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 33ms/step - loss: 0.0015 - mae: 0.0307 - mse: 0.0015 - val_loss: 5.7612e-04 - val_mae: 0.0202 - val_mse: 5.7612e-04
# Epoch 12/100
# 81/82 [============================>.] - ETA: 0s - loss: 0.0014 - mae: 0.0296 - mse: 0.0014WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 33ms/step - loss: 0.0014 - mae: 0.0296 - mse: 0.0014 - val_loss: 9.9557e-04 - val_mae: 0.0272 - val_mse: 9.9557e-04
# Epoch 13/100
# 81/82 [============================>.] - ETA: 0s - loss: 0.0014 - mae: 0.0296 - mse: 0.0014WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 0.0014 - mae: 0.0296 - mse: 0.0014 - val_loss: 0.0017 - val_mae: 0.0367 - val_mse: 0.0017
# Epoch 14/100
# 81/82 [============================>.] - ETA: 0s - loss: 0.0014 - mae: 0.0298 - mse: 0.0014WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 0.0014 - mae: 0.0298 - mse: 0.0014 - val_loss: 5.0427e-04 - val_mae: 0.0175 - val_mse: 5.0427e-04
# Epoch 15/100
# 81/82 [============================>.] - ETA: 0s - loss: 0.0012 - mae: 0.0276 - mse: 0.0012WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 31ms/step - loss: 0.0012 - mae: 0.0276 - mse: 0.0012 - val_loss: 5.9571e-04 - val_mae: 0.0204 - val_mse: 5.9571e-04
# Epoch 16/100
# 81/82 [============================>.] - ETA: 0s - loss: 0.0012 - mae: 0.0269 - mse: 0.0012WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 0.0012 - mae: 0.0270 - mse: 0.0012 - val_loss: 0.0011 - val_mae: 0.0288 - val_mse: 0.0011
# Epoch 17/100
# 81/82 [============================>.] - ETA: 0s - loss: 0.0012 - mae: 0.0277 - mse: 0.0012WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 0.0012 - mae: 0.0276 - mse: 0.0012 - val_loss: 7.5665e-04 - val_mae: 0.0236 - val_mse: 7.5665e-04
# Epoch 18/100
# 81/82 [============================>.] - ETA: 0s - loss: 0.0012 - mae: 0.0270 - mse: 0.0012WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 33ms/step - loss: 0.0012 - mae: 0.0271 - mse: 0.0012 - val_loss: 0.0024 - val_mae: 0.0429 - val_mse: 0.0024
# Epoch 19/100
# 81/82 [============================>.] - ETA: 0s - loss: 0.0012 - mae: 0.0271 - mse: 0.0012WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 33ms/step - loss: 0.0012 - mae: 0.0271 - mse: 0.0012 - val_loss: 0.0013 - val_mae: 0.0284 - val_mse: 0.0013
# Epoch 20/100
# 81/82 [============================>.] - ETA: 0s - loss: 0.0011 - mae: 0.0259 - mse: 0.0011WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 33ms/step - loss: 0.0011 - mae: 0.0259 - mse: 0.0011 - val_loss: 6.7231e-04 - val_mae: 0.0221 - val_mse: 6.7231e-04
# Epoch 21/100
# 81/82 [============================>.] - ETA: 0s - loss: 0.0011 - mae: 0.0257 - mse: 0.0011WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 34ms/step - loss: 0.0011 - mae: 0.0257 - mse: 0.0011 - val_loss: 0.0010 - val_mae: 0.0269 - val_mse: 0.0010
# Epoch 22/100
# 81/82 [============================>.] - ETA: 0s - loss: 0.0010 - mae: 0.0256 - mse: 0.0010WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 33ms/step - loss: 0.0010 - mae: 0.0256 - mse: 0.0010 - val_loss: 7.2025e-04 - val_mae: 0.0231 - val_mse: 7.2025e-04
# Epoch 23/100
# 81/82 [============================>.] - ETA: 0s - loss: 0.0011 - mae: 0.0260 - mse: 0.0011WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 36ms/step - loss: 0.0011 - mae: 0.0260 - mse: 0.0011 - val_loss: 9.7845e-04 - val_mae: 0.0268 - val_mse: 9.7845e-04
# Epoch 24/100
# 81/82 [============================>.] - ETA: 0s - loss: 0.0010 - mae: 0.0255 - mse: 0.0010WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 34ms/step - loss: 0.0010 - mae: 0.0255 - mse: 0.0010 - val_loss: 0.0010 - val_mae: 0.0263 - val_mse: 0.0010
# Epoch 25/100
# 81/82 [============================>.] - ETA: 0s - loss: 9.7263e-04 - mae: 0.0248 - mse: 9.7263e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 33ms/step - loss: 9.7280e-04 - mae: 0.0248 - mse: 9.7280e-04 - val_loss: 3.3122e-04 - val_mae: 0.0144 - val_mse: 3.3122e-04
# Epoch 26/100
# 81/82 [============================>.] - ETA: 0s - loss: 9.8877e-04 - mae: 0.0248 - mse: 9.8877e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 33ms/step - loss: 9.9011e-04 - mae: 0.0248 - mse: 9.9011e-04 - val_loss: 4.2817e-04 - val_mae: 0.0167 - val_mse: 4.2817e-04
# Epoch 27/100
# 81/82 [============================>.] - ETA: 0s - loss: 9.7855e-04 - mae: 0.0247 - mse: 9.7855e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 9.8120e-04 - mae: 0.0247 - mse: 9.8120e-04 - val_loss: 4.6850e-04 - val_mae: 0.0169 - val_mse: 4.6850e-04
# Epoch 28/100
# 81/82 [============================>.] - ETA: 0s - loss: 9.6744e-04 - mae: 0.0246 - mse: 9.6744e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 9.6586e-04 - mae: 0.0246 - mse: 9.6586e-04 - val_loss: 7.2204e-04 - val_mae: 0.0193 - val_mse: 7.2204e-04
# Epoch 29/100
# 81/82 [============================>.] - ETA: 0s - loss: 9.3691e-04 - mae: 0.0243 - mse: 9.3691e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 31ms/step - loss: 9.3751e-04 - mae: 0.0243 - mse: 9.3751e-04 - val_loss: 8.4112e-04 - val_mae: 0.0244 - val_mse: 8.4112e-04
# Epoch 30/100
# 81/82 [============================>.] - ETA: 0s - loss: 9.7630e-04 - mae: 0.0247 - mse: 9.7630e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 9.7639e-04 - mae: 0.0247 - mse: 9.7639e-04 - val_loss: 6.0357e-04 - val_mae: 0.0178 - val_mse: 6.0357e-04
# Epoch 31/100
# 81/82 [============================>.] - ETA: 0s - loss: 9.3289e-04 - mae: 0.0240 - mse: 9.3289e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 9.3487e-04 - mae: 0.0240 - mse: 9.3487e-04 - val_loss: 4.1797e-04 - val_mae: 0.0167 - val_mse: 4.1797e-04
# Epoch 32/100
# 81/82 [============================>.] - ETA: 0s - loss: 9.0175e-04 - mae: 0.0239 - mse: 9.0175e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 33ms/step - loss: 9.0157e-04 - mae: 0.0239 - mse: 9.0157e-04 - val_loss: 5.6158e-04 - val_mae: 0.0189 - val_mse: 5.6158e-04
# Epoch 33/100
# 81/82 [============================>.] - ETA: 0s - loss: 9.6744e-04 - mae: 0.0246 - mse: 9.6744e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 9.6546e-04 - mae: 0.0245 - mse: 9.6546e-04 - val_loss: 3.4207e-04 - val_mae: 0.0148 - val_mse: 3.4207e-04
# Epoch 34/100
# 81/82 [============================>.] - ETA: 0s - loss: 8.7902e-04 - mae: 0.0235 - mse: 8.7902e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 8.7750e-04 - mae: 0.0235 - mse: 8.7750e-04 - val_loss: 6.3789e-04 - val_mae: 0.0195 - val_mse: 6.3789e-04
# Epoch 35/100
# 81/82 [============================>.] - ETA: 0s - loss: 9.0182e-04 - mae: 0.0239 - mse: 9.0182e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 33ms/step - loss: 9.0174e-04 - mae: 0.0239 - mse: 9.0174e-04 - val_loss: 5.8197e-04 - val_mae: 0.0209 - val_mse: 5.8197e-04
# Epoch 36/100
# 81/82 [============================>.] - ETA: 0s - loss: 8.9112e-04 - mae: 0.0238 - mse: 8.9112e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 33ms/step - loss: 8.9060e-04 - mae: 0.0238 - mse: 8.9060e-04 - val_loss: 7.5315e-04 - val_mae: 0.0236 - val_mse: 7.5315e-04
# Epoch 37/100
# 81/82 [============================>.] - ETA: 0s - loss: 8.5388e-04 - mae: 0.0231 - mse: 8.5388e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 33ms/step - loss: 8.5379e-04 - mae: 0.0231 - mse: 8.5379e-04 - val_loss: 6.4105e-04 - val_mae: 0.0208 - val_mse: 6.4105e-04
# Epoch 38/100
# 81/82 [============================>.] - ETA: 0s - loss: 8.7710e-04 - mae: 0.0235 - mse: 8.7710e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 33ms/step - loss: 8.7832e-04 - mae: 0.0235 - mse: 8.7832e-04 - val_loss: 4.8760e-04 - val_mae: 0.0187 - val_mse: 4.8760e-04
# Epoch 39/100
# 81/82 [============================>.] - ETA: 0s - loss: 8.2490e-04 - mae: 0.0227 - mse: 8.2490e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 8.2153e-04 - mae: 0.0226 - mse: 8.2153e-04 - val_loss: 4.1466e-04 - val_mae: 0.0154 - val_mse: 4.1466e-04
# Epoch 40/100
# 81/82 [============================>.] - ETA: 0s - loss: 8.6238e-04 - mae: 0.0231 - mse: 8.6238e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 8.6352e-04 - mae: 0.0231 - mse: 8.6352e-04 - val_loss: 6.1687e-04 - val_mae: 0.0193 - val_mse: 6.1687e-04
# Epoch 41/100
# 81/82 [============================>.] - ETA: 0s - loss: 8.4599e-04 - mae: 0.0231 - mse: 8.4599e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 33ms/step - loss: 8.4560e-04 - mae: 0.0231 - mse: 8.4560e-04 - val_loss: 4.8642e-04 - val_mae: 0.0164 - val_mse: 4.8642e-04
# Epoch 42/100
# 81/82 [============================>.] - ETA: 0s - loss: 8.2597e-04 - mae: 0.0226 - mse: 8.2597e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 33ms/step - loss: 8.2512e-04 - mae: 0.0226 - mse: 8.2512e-04 - val_loss: 8.1638e-04 - val_mae: 0.0228 - val_mse: 8.1638e-04
# Epoch 43/100
# 81/82 [============================>.] - ETA: 0s - loss: 8.7406e-04 - mae: 0.0234 - mse: 8.7406e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 8.7280e-04 - mae: 0.0234 - mse: 8.7280e-04 - val_loss: 3.6607e-04 - val_mae: 0.0150 - val_mse: 3.6607e-04
# Epoch 44/100
# 81/82 [============================>.] - ETA: 0s - loss: 8.7284e-04 - mae: 0.0233 - mse: 8.7284e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 8.7329e-04 - mae: 0.0233 - mse: 8.7329e-04 - val_loss: 7.2714e-04 - val_mae: 0.0190 - val_mse: 7.2714e-04
# Epoch 45/100
# 81/82 [============================>.] - ETA: 0s - loss: 8.3950e-04 - mae: 0.0230 - mse: 8.3950e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 8.4215e-04 - mae: 0.0230 - mse: 8.4215e-04 - val_loss: 3.8383e-04 - val_mae: 0.0166 - val_mse: 3.8383e-04
# Epoch 46/100
# 81/82 [============================>.] - ETA: 0s - loss: 8.6310e-04 - mae: 0.0231 - mse: 8.6310e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 8.6464e-04 - mae: 0.0231 - mse: 8.6464e-04 - val_loss: 7.2154e-04 - val_mae: 0.0224 - val_mse: 7.2154e-04
# Epoch 47/100
# 81/82 [============================>.] - ETA: 0s - loss: 7.8478e-04 - mae: 0.0223 - mse: 7.8478e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 7.8633e-04 - mae: 0.0223 - mse: 7.8633e-04 - val_loss: 7.9553e-04 - val_mae: 0.0234 - val_mse: 7.9553e-04
# Epoch 48/100
# 81/82 [============================>.] - ETA: 0s - loss: 7.6020e-04 - mae: 0.0220 - mse: 7.6020e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 7.6134e-04 - mae: 0.0220 - mse: 7.6134e-04 - val_loss: 6.6663e-04 - val_mae: 0.0211 - val_mse: 6.6663e-04
# Epoch 49/100
# 81/82 [============================>.] - ETA: 0s - loss: 8.1580e-04 - mae: 0.0226 - mse: 8.1580e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 8.1614e-04 - mae: 0.0226 - mse: 8.1614e-04 - val_loss: 7.7864e-04 - val_mae: 0.0236 - val_mse: 7.7864e-04
# Epoch 50/100
# 81/82 [============================>.] - ETA: 0s - loss: 8.1527e-04 - mae: 0.0225 - mse: 8.1527e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 31ms/step - loss: 8.1354e-04 - mae: 0.0224 - mse: 8.1354e-04 - val_loss: 4.8976e-04 - val_mae: 0.0176 - val_mse: 4.8976e-04
# Epoch 51/100
# 81/82 [============================>.] - ETA: 0s - loss: 7.5467e-04 - mae: 0.0218 - mse: 7.5467e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 7.5557e-04 - mae: 0.0218 - mse: 7.5557e-04 - val_loss: 6.6747e-04 - val_mae: 0.0208 - val_mse: 6.6747e-04
# Epoch 52/100
# 81/82 [============================>.] - ETA: 0s - loss: 8.0415e-04 - mae: 0.0223 - mse: 8.0415e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 31ms/step - loss: 8.0478e-04 - mae: 0.0223 - mse: 8.0478e-04 - val_loss: 0.0013 - val_mae: 0.0310 - val_mse: 0.0013
# Epoch 53/100
# 81/82 [============================>.] - ETA: 0s - loss: 8.4216e-04 - mae: 0.0228 - mse: 8.4216e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 8.4447e-04 - mae: 0.0228 - mse: 8.4447e-04 - val_loss: 4.6435e-04 - val_mae: 0.0165 - val_mse: 4.6435e-04
# Epoch 54/100
# 81/82 [============================>.] - ETA: 0s - loss: 8.2547e-04 - mae: 0.0228 - mse: 8.2547e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 8.2563e-04 - mae: 0.0228 - mse: 8.2563e-04 - val_loss: 4.6703e-04 - val_mae: 0.0166 - val_mse: 4.6703e-04
# Epoch 55/100
# 81/82 [============================>.] - ETA: 0s - loss: 7.9425e-04 - mae: 0.0224 - mse: 7.9425e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 7.9309e-04 - mae: 0.0224 - mse: 7.9309e-04 - val_loss: 6.0347e-04 - val_mae: 0.0201 - val_mse: 6.0347e-04
# Epoch 56/100
# 81/82 [============================>.] - ETA: 0s - loss: 7.6179e-04 - mae: 0.0218 - mse: 7.6179e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 33ms/step - loss: 7.5965e-04 - mae: 0.0217 - mse: 7.5965e-04 - val_loss: 6.8362e-04 - val_mae: 0.0222 - val_mse: 6.8362e-04
# Epoch 57/100
# 81/82 [============================>.] - ETA: 0s - loss: 7.5379e-04 - mae: 0.0219 - mse: 7.5379e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 7.5392e-04 - mae: 0.0219 - mse: 7.5392e-04 - val_loss: 4.8140e-04 - val_mae: 0.0166 - val_mse: 4.8140e-04
# Epoch 58/100
# 81/82 [============================>.] - ETA: 0s - loss: 7.0710e-04 - mae: 0.0210 - mse: 7.0710e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 7.0712e-04 - mae: 0.0210 - mse: 7.0712e-04 - val_loss: 9.0300e-04 - val_mae: 0.0253 - val_mse: 9.0300e-04
# Epoch 59/100
# 81/82 [============================>.] - ETA: 0s - loss: 7.6373e-04 - mae: 0.0218 - mse: 7.6373e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 7.6163e-04 - mae: 0.0217 - mse: 7.6163e-04 - val_loss: 8.4562e-04 - val_mae: 0.0223 - val_mse: 8.4562e-04
# Epoch 60/100
# 81/82 [============================>.] - ETA: 0s - loss: 7.1304e-04 - mae: 0.0212 - mse: 7.1304e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 7.1306e-04 - mae: 0.0212 - mse: 7.1306e-04 - val_loss: 7.8283e-04 - val_mae: 0.0226 - val_mse: 7.8283e-04
# Epoch 61/100
# 81/82 [============================>.] - ETA: 0s - loss: 7.1298e-04 - mae: 0.0211 - mse: 7.1298e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 31ms/step - loss: 7.1359e-04 - mae: 0.0211 - mse: 7.1359e-04 - val_loss: 5.0244e-04 - val_mae: 0.0181 - val_mse: 5.0244e-04
# Epoch 62/100
# 81/82 [============================>.] - ETA: 0s - loss: 8.0868e-04 - mae: 0.0223 - mse: 8.0868e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 33ms/step - loss: 8.1054e-04 - mae: 0.0223 - mse: 8.1054e-04 - val_loss: 6.0918e-04 - val_mae: 0.0198 - val_mse: 6.0918e-04
# Epoch 63/100
# 81/82 [============================>.] - ETA: 0s - loss: 8.1153e-04 - mae: 0.0223 - mse: 8.1153e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 31ms/step - loss: 8.0993e-04 - mae: 0.0223 - mse: 8.0993e-04 - val_loss: 9.0804e-04 - val_mae: 0.0254 - val_mse: 9.0804e-04
# Epoch 64/100
# 81/82 [============================>.] - ETA: 0s - loss: 7.0597e-04 - mae: 0.0211 - mse: 7.0597e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 31ms/step - loss: 7.0715e-04 - mae: 0.0211 - mse: 7.0715e-04 - val_loss: 6.4947e-04 - val_mae: 0.0211 - val_mse: 6.4947e-04
# Epoch 65/100
# 81/82 [============================>.] - ETA: 0s - loss: 7.0117e-04 - mae: 0.0210 - mse: 7.0117e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 6.9969e-04 - mae: 0.0210 - mse: 6.9969e-04 - val_loss: 6.8027e-04 - val_mae: 0.0216 - val_mse: 6.8027e-04
# Epoch 66/100
# 81/82 [============================>.] - ETA: 0s - loss: 6.9972e-04 - mae: 0.0210 - mse: 6.9972e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 7.0007e-04 - mae: 0.0210 - mse: 7.0007e-04 - val_loss: 6.6397e-04 - val_mae: 0.0219 - val_mse: 6.6397e-04
# Epoch 67/100
# 81/82 [============================>.] - ETA: 0s - loss: 7.2508e-04 - mae: 0.0213 - mse: 7.2508e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 31ms/step - loss: 7.2485e-04 - mae: 0.0212 - mse: 7.2485e-04 - val_loss: 0.0016 - val_mae: 0.0296 - val_mse: 0.0016
# Epoch 68/100
# 81/82 [============================>.] - ETA: 0s - loss: 7.5956e-04 - mae: 0.0219 - mse: 7.5956e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 7.6021e-04 - mae: 0.0219 - mse: 7.6021e-04 - val_loss: 7.2083e-04 - val_mae: 0.0233 - val_mse: 7.2083e-04
# Epoch 69/100
# 81/82 [============================>.] - ETA: 0s - loss: 7.1826e-04 - mae: 0.0212 - mse: 7.1826e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 7.1766e-04 - mae: 0.0212 - mse: 7.1766e-04 - val_loss: 9.5459e-04 - val_mae: 0.0267 - val_mse: 9.5459e-04
# Epoch 70/100
# 81/82 [============================>.] - ETA: 0s - loss: 7.2397e-04 - mae: 0.0212 - mse: 7.2397e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 31ms/step - loss: 7.2319e-04 - mae: 0.0211 - mse: 7.2319e-04 - val_loss: 0.0014 - val_mae: 0.0281 - val_mse: 0.0014
# Epoch 71/100
# 81/82 [============================>.] - ETA: 0s - loss: 6.6974e-04 - mae: 0.0205 - mse: 6.6974e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 31ms/step - loss: 6.7003e-04 - mae: 0.0205 - mse: 6.7003e-04 - val_loss: 6.3594e-04 - val_mae: 0.0213 - val_mse: 6.3594e-04
# Epoch 72/100
# 81/82 [============================>.] - ETA: 0s - loss: 6.7879e-04 - mae: 0.0205 - mse: 6.7879e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 31ms/step - loss: 6.7885e-04 - mae: 0.0205 - mse: 6.7885e-04 - val_loss: 9.9803e-04 - val_mae: 0.0280 - val_mse: 9.9803e-04
# Epoch 73/100
# 81/82 [============================>.] - ETA: 0s - loss: 6.5152e-04 - mae: 0.0202 - mse: 6.5152e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 6.5057e-04 - mae: 0.0202 - mse: 6.5057e-04 - val_loss: 7.2744e-04 - val_mae: 0.0224 - val_mse: 7.2744e-04
# Epoch 74/100
# 81/82 [============================>.] - ETA: 0s - loss: 6.7820e-04 - mae: 0.0206 - mse: 6.7820e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 6.8028e-04 - mae: 0.0206 - mse: 6.8028e-04 - val_loss: 5.6943e-04 - val_mae: 0.0196 - val_mse: 5.6943e-04
# Epoch 75/100
# 81/82 [============================>.] - ETA: 0s - loss: 6.8477e-04 - mae: 0.0208 - mse: 6.8477e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 33ms/step - loss: 6.8681e-04 - mae: 0.0208 - mse: 6.8681e-04 - val_loss: 4.6888e-04 - val_mae: 0.0174 - val_mse: 4.6888e-04
# Epoch 76/100
# 81/82 [============================>.] - ETA: 0s - loss: 7.2082e-04 - mae: 0.0212 - mse: 7.2082e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 7.2066e-04 - mae: 0.0212 - mse: 7.2066e-04 - val_loss: 6.3114e-04 - val_mae: 0.0206 - val_mse: 6.3114e-04
# Epoch 77/100
# 81/82 [============================>.] - ETA: 0s - loss: 6.6451e-04 - mae: 0.0204 - mse: 6.6451e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 6.6593e-04 - mae: 0.0204 - mse: 6.6593e-04 - val_loss: 6.8097e-04 - val_mae: 0.0219 - val_mse: 6.8097e-04
# Epoch 78/100
# 81/82 [============================>.] - ETA: 0s - loss: 6.4733e-04 - mae: 0.0203 - mse: 6.4733e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 31ms/step - loss: 6.4636e-04 - mae: 0.0203 - mse: 6.4636e-04 - val_loss: 0.0013 - val_mae: 0.0301 - val_mse: 0.0013
# Epoch 79/100
# 81/82 [============================>.] - ETA: 0s - loss: 6.7236e-04 - mae: 0.0206 - mse: 6.7236e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 6.7100e-04 - mae: 0.0206 - mse: 6.7100e-04 - val_loss: 6.4285e-04 - val_mae: 0.0207 - val_mse: 6.4285e-04
# Epoch 80/100
# 81/82 [============================>.] - ETA: 0s - loss: 6.1641e-04 - mae: 0.0197 - mse: 6.1641e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 6.1589e-04 - mae: 0.0197 - mse: 6.1589e-04 - val_loss: 7.8876e-04 - val_mae: 0.0232 - val_mse: 7.8876e-04
# Epoch 81/100
# 81/82 [============================>.] - ETA: 0s - loss: 6.6167e-04 - mae: 0.0204 - mse: 6.6167e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 6.6344e-04 - mae: 0.0204 - mse: 6.6344e-04 - val_loss: 9.5048e-04 - val_mae: 0.0267 - val_mse: 9.5048e-04
# Epoch 82/100
# 81/82 [============================>.] - ETA: 0s - loss: 6.7366e-04 - mae: 0.0206 - mse: 6.7366e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 6.7266e-04 - mae: 0.0206 - mse: 6.7266e-04 - val_loss: 6.6456e-04 - val_mae: 0.0221 - val_mse: 6.6456e-04
# Epoch 83/100
# 81/82 [============================>.] - ETA: 0s - loss: 6.1156e-04 - mae: 0.0195 - mse: 6.1156e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 6.1264e-04 - mae: 0.0196 - mse: 6.1264e-04 - val_loss: 7.2410e-04 - val_mae: 0.0212 - val_mse: 7.2410e-04
# Epoch 84/100
# 81/82 [============================>.] - ETA: 0s - loss: 5.9471e-04 - mae: 0.0193 - mse: 5.9471e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 5.9473e-04 - mae: 0.0193 - mse: 5.9473e-04 - val_loss: 7.5260e-04 - val_mae: 0.0234 - val_mse: 7.5260e-04
# Epoch 85/100
# 81/82 [============================>.] - ETA: 0s - loss: 6.1964e-04 - mae: 0.0197 - mse: 6.1964e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 33ms/step - loss: 6.2072e-04 - mae: 0.0197 - mse: 6.2072e-04 - val_loss: 7.3765e-04 - val_mae: 0.0227 - val_mse: 7.3765e-04
# Epoch 86/100
# 81/82 [============================>.] - ETA: 0s - loss: 6.2978e-04 - mae: 0.0199 - mse: 6.2978e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 33ms/step - loss: 6.2927e-04 - mae: 0.0199 - mse: 6.2927e-04 - val_loss: 7.8946e-04 - val_mae: 0.0236 - val_mse: 7.8946e-04
# Epoch 87/100
# 81/82 [============================>.] - ETA: 0s - loss: 7.2733e-04 - mae: 0.0211 - mse: 7.2733e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 33ms/step - loss: 7.2812e-04 - mae: 0.0211 - mse: 7.2812e-04 - val_loss: 6.3084e-04 - val_mae: 0.0213 - val_mse: 6.3084e-04
# Epoch 88/100
# 81/82 [============================>.] - ETA: 0s - loss: 6.7919e-04 - mae: 0.0205 - mse: 6.7919e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 6.7955e-04 - mae: 0.0205 - mse: 6.7955e-04 - val_loss: 8.8529e-04 - val_mae: 0.0254 - val_mse: 8.8529e-04
# Epoch 89/100
# 81/82 [============================>.] - ETA: 0s - loss: 5.9933e-04 - mae: 0.0195 - mse: 5.9933e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 5.9912e-04 - mae: 0.0195 - mse: 5.9912e-04 - val_loss: 8.7128e-04 - val_mae: 0.0249 - val_mse: 8.7128e-04
# Epoch 90/100
# 81/82 [============================>.] - ETA: 0s - loss: 5.9015e-04 - mae: 0.0193 - mse: 5.9015e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 31ms/step - loss: 5.9031e-04 - mae: 0.0193 - mse: 5.9031e-04 - val_loss: 7.8353e-04 - val_mae: 0.0239 - val_mse: 7.8353e-04
# Epoch 91/100
# 81/82 [============================>.] - ETA: 0s - loss: 5.8647e-04 - mae: 0.0191 - mse: 5.8647e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 5.8746e-04 - mae: 0.0191 - mse: 5.8746e-04 - val_loss: 0.0011 - val_mae: 0.0275 - val_mse: 0.0011
# Epoch 92/100
# 81/82 [============================>.] - ETA: 0s - loss: 6.0868e-04 - mae: 0.0195 - mse: 6.0868e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 33ms/step - loss: 6.0878e-04 - mae: 0.0195 - mse: 6.0878e-04 - val_loss: 8.6697e-04 - val_mae: 0.0256 - val_mse: 8.6697e-04
# Epoch 93/100
# 81/82 [============================>.] - ETA: 0s - loss: 5.9044e-04 - mae: 0.0192 - mse: 5.9044e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 33ms/step - loss: 5.8986e-04 - mae: 0.0192 - mse: 5.8986e-04 - val_loss: 6.7228e-04 - val_mae: 0.0220 - val_mse: 6.7228e-04
# Epoch 94/100
# 81/82 [============================>.] - ETA: 0s - loss: 5.7540e-04 - mae: 0.0191 - mse: 5.7540e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 33ms/step - loss: 5.7574e-04 - mae: 0.0191 - mse: 5.7574e-04 - val_loss: 5.9198e-04 - val_mae: 0.0205 - val_mse: 5.9198e-04
# Epoch 95/100
# 81/82 [============================>.] - ETA: 0s - loss: 6.1112e-04 - mae: 0.0195 - mse: 6.1112e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 33ms/step - loss: 6.0998e-04 - mae: 0.0195 - mse: 6.0998e-04 - val_loss: 0.0012 - val_mae: 0.0284 - val_mse: 0.0012
# Epoch 96/100
# 81/82 [============================>.] - ETA: 0s - loss: 5.8680e-04 - mae: 0.0190 - mse: 5.8680e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 5.8619e-04 - mae: 0.0190 - mse: 5.8619e-04 - val_loss: 8.4910e-04 - val_mae: 0.0253 - val_mse: 8.4910e-04
# Epoch 97/100
# 81/82 [============================>.] - ETA: 0s - loss: 5.9506e-04 - mae: 0.0193 - mse: 5.9506e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 33ms/step - loss: 5.9361e-04 - mae: 0.0193 - mse: 5.9361e-04 - val_loss: 0.0017 - val_mae: 0.0297 - val_mse: 0.0017
# Epoch 98/100
# 81/82 [============================>.] - ETA: 0s - loss: 6.3805e-04 - mae: 0.0201 - mse: 6.3805e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 33ms/step - loss: 6.3844e-04 - mae: 0.0201 - mse: 6.3844e-04 - val_loss: 9.8828e-04 - val_mae: 0.0259 - val_mse: 9.8828e-04
# Epoch 99/100
# 81/82 [============================>.] - ETA: 0s - loss: 5.9114e-04 - mae: 0.0193 - mse: 5.9114e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 5.9127e-04 - mae: 0.0193 - mse: 5.9127e-04 - val_loss: 0.0011 - val_mae: 0.0276 - val_mse: 0.0011
# Epoch 100/100
# 81/82 [============================>.] - ETA: 0s - loss: 5.7562e-04 - mae: 0.0190 - mse: 5.7562e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 82/82 [==============================] - 3s 32ms/step - loss: 5.7482e-04 - mae: 0.0190 - mse: 5.7482e-04 - val_loss: 7.4272e-04 - val_mae: 0.0236 - val_mse: 7.4272e-04

# %%
plt.plot(history.history['mse'])
plt.plot(history.history['val_mse'])
plt.title('Mean Squared Error of SIE Prediction')
plt.ylabel('MSE')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

plt.plot(history.history['mae'])
plt.plot(history.history['val_mae'])
plt.title('Mean Absolute Error of SIE Prediction')
plt.ylabel('MAE')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss of SIE Prediction')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
from numpy import sqrt

#model.load_weights("weights.best.hdf5")

cols = len(df.columns)
pred = model.predict(X_test)

predicted_dataset = dataset
predicted_dataset[len(predicted_dataset)-len(pred):, cols-1] = pred[:, 0]
scaled_predicted_dataset = scaler.inverse_transform(predicted_dataset)

predicted_df = df.copy()
predicted_df['sea_ice_extent'][len(predicted_dataset)-len(pred):] = scaled_predicted_dataset[len(predicted_dataset)-len(pred):, cols-1]

predictions = pd.DataFrame()
predictions['predicted'] = (predicted_df['sea_ice_extent'][len(predicted_dataset)-len(pred):])
predictions['actual'] = (df['sea_ice_extent'][len(predicted_dataset)-len(pred):])
predictions = predictions.astype(float)
# Out:
# 46/46 [==============================] - 1s 9ms/step

# %%
# !pip install --upgrade seaborn

# %%
plt.figure(figsize = (16,6))
ax = plt.axes()
# ax.set_facecolor('#dcdcdc')

plt.title('Arctic Sea Ice Extent Actual vs Prediction Curve for Test Data', fontsize = 20,fontweight = "bold")
plt.xlabel('Time' , fontsize = 14,fontweight = "bold")
plt.ylabel('Sea Ice Extent (10\u2076 km\u00b2)', fontsize = 14,fontweight = "bold")
plt.plot(predictions['actual']/10**6, 'blue', label='Actual SIE')
plt.plot(predictions['predicted']/10**6, 'red', label='Predicted SIE')
plt.legend()
plt.grid()
plt.show

predictions['diff'] = predictions['predicted'] - predictions['actual']
plt.figure(figsize=(10,10))
plt.xlabel('Difference between actual and predicted SIE (10\u2076 km\u00b2)')
sns.histplot(predictions['diff'])
plt.title('Distribution of differences between actual and predicted SIE')
plt.show()

mspe = (np.mean(np.square((predictions['actual'].values - predictions['predicted'].values) / predictions['actual'].values))) * 100
rmspe = (np.sqrt(np.mean(np.square((predictions['actual'].values - predictions['predicted'].values) / predictions['actual'].values)))) * 100

print("MSE : ", mean_squared_error(predictions['predicted'].values, predictions['actual'].values), "(10\u2076 km\u00b2)")
print("MSPE :", mspe, "%")
print("RMSE : ", sqrt(mean_squared_error(predictions['predicted'].values, predictions['actual'].values)), "(10\u2076 km\u00b2)")
print("RMSPE :", rmspe, "%")
print("MAE : ", mean_absolute_error(predictions['predicted'].values, predictions['actual'].values), "(10\u2076 km\u00b2)")
print("MAPE : ", mean_absolute_percentage_error(predictions['predicted'].values, predictions['actual'].values)*100, "%")
print("R2 : ", r2_score(predictions['predicted'].values, predictions['actual'].values))
# Out:
# MSE :  244859297591.37466 (10⁶ km²)
# MSPE : 0.5632255612875302 %
# RMSE :  494832.59552233893 (10⁶ km²)
# RMSPE : 7.5048355164355876 %
# MAE :  371165.9593383873 (10⁶ km²)
# MAPE :  4.346242547355995 %
# R2 :  0.9758149404169573

# %%
# while True:pass
